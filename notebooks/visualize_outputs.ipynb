# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as mp
import seaborn as sns
sns.set()
#sns.set_context("paper")
# %matplotlib inline

# %%
splitnum = 3
meltype = 2
if meltype == 1:
    olap = 0.4
    nu = 'n015'
else:
    olap = 0.5
    nu = 'n005'

outdir = "/Users/rachelbittner/Desktop/exper_output/ver1"

# %%
melodia_df = (pd.io.json.read_json("melodia_scores/melody%s/nu_%s_melody%s.json" % (meltype, nu, meltype))).transpose()
clf_df = pd.DataFrame.from_csv("%s/CC_exper_mel%s/splitnum_%s/olap_%s/all_mel_scores.csv" % (outdir, meltype, splitnum, olap))
diff_df = pd.DataFrame(columns=['OA melodia', 'OA clf', 'Diff'])
diff_df.loc[:, 'OA melodia'] = melodia_df.loc[clf_df.index, 'Overall Accuracy']
diff_df.loc[:, 'OA clf'] = clf_df['OA']
diff_df.loc[:, 'Diff'] = melodia_df.loc[clf_df.index, 'Overall Accuracy'] - clf_df['OA']
print diff_df
print diff_df.describe()
# Out:
#                                        OA melodia    OA clf      Diff
# Phoenix_SeanCaughlinsTheScartaglen       0.515244  0.468565  0.046679
# MusicDelta_LatinJazz                     0.529300  0.376734  0.152566
# MusicDelta_FunkJazz                      0.607898  0.639281 -0.031382
# Phoenix_ElzicsFarewell                   0.334339  0.353304 -0.018965
# Phoenix_LarkOnTheStrandDrummondCastle    0.511190  0.645931 -0.134741
# MatthewEntwistle_ImpressionsOfSaturn     0.526184  0.490820  0.035364
# SweetLights_YouLetMeDown                 0.563910  0.508493  0.055417
# Phoenix_BrokenPledgeChicagoReel          0.501287  0.534522 -0.033235
# MatthewEntwistle_FairerHopes             0.264697  0.325380 -0.060683
# Creepoid_OldTree                         0.538993  0.598233 -0.059239
# Phoenix_ColliersDaughter                 0.594568  0.580319  0.014249
# MusicDelta_InTheHalloftheMountainKing    0.053245  0.112479 -0.059235
# MatthewEntwistle_TheArch                 0.723347  0.587746  0.135600
# MatthewEntwistle_Lontano                 0.307679  0.257675  0.050004
# MatthewEntwistle_TheFlaxenField          0.451285  0.441201  0.010084
# HeladoNegro_MitadDelMundo                0.619466  0.508826  0.110639
# MatthewEntwistle_DontYouEver             0.639344  0.554730  0.084615
# MichaelKropf_AllGoodThings               0.382473  0.453482 -0.071009
# PortStWillow_StayEven                    0.577832  0.403765  0.174067
# Phoenix_ScotchMorris                     0.624656  0.653002 -0.028346
# MusicDelta_Pachelbel                     0.311158  0.382343 -0.071185
#        OA melodia     OA clf       Diff
# count   21.000000  21.000000  21.000000
# mean     0.484671   0.470325   0.014346
# std      0.158045   0.137777   0.083236
# min      0.053245   0.112479  -0.134741
# 25%      0.382473   0.382343  -0.059235
# 50%      0.526184   0.490820   0.010084
# 75%      0.594568   0.580319   0.055417
# max      0.723347   0.653002   0.174067

# %%
trackid='MusicDelta_LatinJazz'

# %%
clf_fpath = "%s/CC_exper_mel%s/splitnum_%s/olap_%s/melody_output/%s_pred.csv" % (outdir, meltype, splitnum, olap, trackid)
melodia_fpath = "Melodia_Output_nu/nu_%s/%s_MIX_vamp_mtg-melodia-nu_melodianu_melody.csv" % (nu, trackid)
annot_fpath = "/Datasets/MedleyDB/Annotations/Melody_Annotations/MELODY%s/%s_MELODY%s.csv" % (meltype, trackid, meltype)

# %%
clf_dat = pd.read_csv(clf_fpath, header=None, index_col=None)
clf_dat.columns = ['time', 'f0']
melodia_dat = pd.read_csv(melodia_fpath, header=None, index_col=None)
melodia_dat.columns = ['time', 'f0']
melodia_dat.loc[melodia_dat['f0'] < 0,'f0'] = 0
annot = pd.read_csv(annot_fpath, header=None, index_col=None)
annot.columns = ['time', 'f0']

# %%
ymin = 256
ymax = 1024
xlim = [48, 66]
c1, c2 = sns.color_palette('deep', 2)

ant = mp.Patch(color='k', label='Annotation: Melody %s' % meltype)
clf = mp.Patch(color=c1, label='Classification Method')
mda = mp.Patch(color=c2, label='Melodia')

fig = plt.figure()

ax1 = plt.subplot(2,1,1)
plt.semilogy(annot['time'], annot['f0'], 'ok', alpha=1, basey=2, markersize=5)
plt.semilogy(clf_dat['time'], clf_dat['f0'], '.', color=c1, alpha=1, basey=2, markersize=3)
ax1.set_ylim(ymin=ymin, ymax=ymax)
plt.xlim(xlim)
locs,labels = plt.yticks()
plt.yticks(locs, map(lambda x: "%1.0f" % x, locs))
plt.ylabel('Frequency (Hz)')
plt.tick_params(axis='x', which='both', bottom='off', top='off', labelbottom='off')

ax2 = plt.subplot(2,1,2)
plt.semilogy(annot['time'], annot['f0'], 'ok', alpha=1, basey=2, markersize=5)
plt.semilogy(melodia_dat['time'], melodia_dat['f0'], '.', color=c2, alpha=1, basey=2, markersize=3)
ax2.set_ylim(ymin=ymin, ymax=ymax)
plt.xlim(xlim)
locs,labels = plt.yticks()
plt.yticks(locs, map(lambda x: "%1.0f" % x, locs))
plt.xlabel('Time (sec)')
plt.ylabel('Frequency (Hz)')

fig.legend(handles=[ant, clf, mda], labels=['Melody %s Annotation' % meltype,'Proposed Method','Melodia'], 
           loc=(0.125,0.52), ncol=3, columnspacing=1)
plt.savefig('/Users/rachelbittner/Desktop/mel%s_%s_comparison.eps' % (meltype, trackid), format='eps', bbox_inches='tight', pad_inches=0.0)

# %%
0
